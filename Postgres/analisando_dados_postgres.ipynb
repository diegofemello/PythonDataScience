# %%
import pandas as pd
from IPython.display import display
import plotly.express as px

SQLALCHEMY_DATABASE_URI = 'postgresql+psycopg2://{0}:{1}@{2}:{3}/{4}?\
    options'.format(
    "postgres",
    "Jn&Mw4eD",
    "165.22.178.111",
    "5432",
    "xpd"
)

eventlog = pd.read_sql_query(
    "SELECT * FROM eventlog",
    SQLALCHEMY_DATABASE_URI
)

display(eventlog)
# Out:
#         id  accelerationtimelimit contractindicator  decelerationtimelimit  \
# 0        1                    0.0              True                    0.0
# 1        2                    0.0              True                    0.0
# 2        3                    0.0              True                    0.0
# 3        4                    5.0              True                    5.0
# 4        5                    0.0              True                    0.0
# ...    ...                    ...               ...                    ...
# 4374  4366                    0.0              None                    0.0
# 4375  4370                    0.0              None                    0.0
# 4376  4371                   20.0              True                    5.0
# 4377  4373                   20.0              True                    5.0
# 4378  4379                    0.0              None                    0.0
#
# ...

# %%
graph = px.histogram(eventlog, x="accelerationtimelimit", color="decelerationtimelimit")

graph.show()

# %%
import pandas as pd

# ler arquivo json

file = pd.read_json("histogram.json")
file_normalized = pd.json_normalize(file.data)
display(file_normalized)
# Out:
#    diffOp     voptimum    vstandard        vpoor  \
# 0    None     4.000000     3.000000     2.000000
# 1    None    38.000000    33.000000    23.000000
# 2    None    38.000000    33.000000    23.000000
# 3    None     1.000000     1.000000     1.000000
# 4    None     0.100000     0.083333     0.071429
# 5    None  2100.000000  1800.000000  1200.000000
# 6    None   100.000000    70.000000    50.000000
# 7    None     1.000000     1.000000     1.000000
# 8    None  2100.000000  1800.000000  1200.000000
# 9    None    38.000000    33.000000    23.000000
# 10   None    10.714286    10.000000     7.000000
# 11   None     0.400000     0.400000     0.400000
# 12   None     0.200000     0.166667     0.142857
# 13   None    10.000000    10.000000    10.000000
# 14   None     1.000000     0.500000     0.333333
# 15   None   100.000000    60.000000    40.000000
# 16   None    38.000000    33.000000    23.000000
# 17   None   180.000000   160.000000   140.000000
# ...

# %%
casing_connection = file_normalized[file_normalized.label == "Casing Connection"]
points = casing_connection.points.values.tolist()[0]
points_dataframe = pd.DataFrame(list(points), columns=["x", "y"])

casing_connection = casing_connection.drop(columns=["points"])

# display(casing_connection)
# display(points_dataframe)

import matplotlib.pyplot as plt

plt.scatter(points_dataframe.x,points_dataframe.y, label="Casing Connection", s=10)
plt.legend()

plt.show()
